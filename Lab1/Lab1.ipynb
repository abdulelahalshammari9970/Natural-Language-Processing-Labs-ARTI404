# %% [markdown]
# ### Abdulelah Mohsen Alshammari    -    2240005261

# %%
import urllib.request
import pandas as pd

# Download a sample CSV dataset
url = 'https://raw.githubusercontent.com/fivethirtyeight/data/master/airline-safety/airline-safety.csv'
dataset_path = 'airline-safety.csv'
urllib.request.urlretrieve(url, dataset_path)
print(' the Dataset downloaded successfully! ')
# Out:
#  the Dataset downloaded successfully!

# %%
# Open and display the dataset
df = pd.read_csv(dataset_path)
df.head()
# Out:
#                  airline  avail_seat_km_per_week  incidents_85_99  \
# 0             Aer Lingus               320906734                2
# 1              Aeroflot*              1197672318               76
# 2  Aerolineas Argentinas               385803648                6
# 3            Aeromexico*               596871813                3
# 4             Air Canada              1865253802                2
#
#    fatal_accidents_85_99  fatalities_85_99  incidents_00_14  \
# 0                      0                 0                0
# 1                     14               128                6
# 2                      0                 0                1
# 3                      1                64                5
# 4                      0                 0                2
#
#    fatal_accidents_00_14  fatalities_00_14
# 0                      0                 0
# 1                      1                88
# 2                      0                 0
# 3                      0                 0
# 4                      0                 0
